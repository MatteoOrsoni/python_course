# %% [markdown]
# <h1 style="text-align: center;">Module 4: End-to-End Project (Capstone)</h1>

# %% [markdown]
# <font size="4">In this final module, you will act as the Lead Data Analyst for a psychological study.</font>
#
# <font size="4">You have received a raw dataset from a research team investigating the effectiveness of different therapeutic interventions on Anxiety and Cognitive Performance.
#
# <font size="4">Your goal is to import, clean, analyze, and visualize the data to answer specific research questions.
#
# | <font size="4">Variable         | <font size="4">Description                                                | <font size="4">Type            |
# | ---------------- | ---------------------------------------------------------- | --------------- |
# | <font size="4">Participant_ID   | <font size="4">Unique ID for each subject                                 | <font size="4">Numeric         |
# | <font size="4">Age              | <font size="4">Age of the participant (Years)                             | <font size="4">Numeric         |
# | <font size="4">Gender           | <font size="4">Self-identified gender                                     | <font size="4">Categorical     |
# | <font size="4">Education_Level  | <font size="4">Highest degree obtained                                    | <font size="4">Categorical     |
# | <font size="4">Group            | <font size="4">Experimental condition (Control, CBT_Therapy, Mindfulness) | <font size="4">Categorical     |
# | <font size="4">STAI_Pre         | <font size="4">State-Trait Anxiety Inventory Score (Pre-Intervention)     | <font size="4">Numeric (20-80) |
# | <font size="4">STAI_Post        | <font size="4">State-Trait Anxiety Inventory Score (Post-Intervention)    | <font size="4">Numeric (20-80) |
# | <font size="4">BDI_Score        | <font size="4">Beck Depression Inventory Score                            | <font size="4">Numeric (0-63)  |
# | <font size="4">Reaction_Time_ms | <font size="4">Avg reaction time in a cognitive task                      | <font size="4">Numeric (ms)    |
# | <font size="4">Accuracy_Pct     | <font size="4">Accuracy percentage in the cognitive task                  | <font size="4">Numeric (0-100) |
#
# <font size="4">**Note**: The dataset contains missing values (NaN) that simulate real-world data collection errors (~5% missingness).</font>

# %% [markdown]
# <font size="4">**Research Questions (Objectives)**
#
# <font size="4">You need to produce a Jupyter Notebook that addresses the following:
#
# - <font size="4">**Data Cleaning**: How many missing values are there? Fix them appropriately (e.g., impute Age with median, drop rows if critical scores are missing).
#
# - <font size="4">**Feature Engineering**:
#
#     - <font size="4">Create a new column Anxiety_Reduction = (STAI_Pre - STAI_Post).
#
#     - <font size="4">Create a binary column High_Depression: True if BDI_Score > 29 (Severe), else False.
#
# - <font size="4">**Group Analysis**: Which therapy group showed the largest reduction in anxiety?
#
# - <font size="4">**Correlation Analysis**: Is there a relationship between Anxiety (STAI_Pre) and Cognitive Performance (Reaction_Time_ms)?
#
# - <font size="4">**Visualization**:
#
#     - <font size="4">A Box Plot comparing Anxiety_Reduction across the 3 Groups.
#     - <font size="4">A Scatter Plot of Reaction_Time_ms vs. Accuracy_Pct.
#
#
# <font size="5" style="text-align: center;">**Save the Notebook as a PDF and send to Prof.Benassi Mariagrazia, and Dr.Matteo Orsoni mail contacts.**
#
# ![image.png](attachment:34961f35-acc1-458a-80df-70921addaf64.png)
